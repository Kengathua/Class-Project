# %%
import os
import datetime
from datetime import date
import requests
from bs4 import BeautifulSoup

import datetime
from datetime import date
import requests
from bs4 import BeautifulSoup

import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException

from pandas_datareader._utils import RemoteDataError

import csv

options = Options()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')

driver = webdriver.Chrome(
    "/usr/bin/chromedriver", options=options)

# %%
base = datetime.datetime.today().date()
date_list = [base - datetime.timedelta(days=x) for x in range(5)]

# print(str(date_list[0]).replace('-', ''))

for date in date_list:
  day = str(date).replace('-', '')
  print(day)

# %%
url='https://live.mystocks.co.ke/price_list/20211103'

page = requests.get(url)

soup = BeautifulSoup(page.content, "html.parser")

trs = soup.find('div', id='main').find('table', id='pricelist').find('tr', class_="row").find('td')

sectors = trs.find('td', class_="b2").find_all('h3')

tickers = trs.find_all('td', class_="nm")

companies = trs.find('td', class_="nm").find_all('a')

driver.get(url)
stocks=[]
tickers=[]

for i in range(3,88):
    try:
        # ticker_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[1]'.format(i)
        # ticker = driver.find_element_by_xpath(ticker_xpath).text

        # tickers.append(ticker)
        # try:
        #     sector_xpath='//*[@id="pricelist"]/tbody/tr[{}]/td/h3'.format(i)
        #     sector = driver.find_element_by_xpath(sector_xpath).text
        #     if sector:
        #         tickers.remove(sector)
            
        #     else:
        #         pass
        # except NoSuchElementException:
        #     pass


        sector_xpath = '//*[@id="pricelist"]/tbody/tr[{}]'.format(i)
        ticker_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[1]'.format(i)
        company_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[2]/a'.format(i)
        low_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[5]'.format(i)
        high_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[6]'.format(i)
        current_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[7]'.format(i)
        open_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[8]'.format(i)
        volume_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[12]'.format(i)


        stock=[]
        sector = driver.find_element_by_xpath(sector_xpath).text
        # print(sector)
        stock.append(sector)
        ticker = driver.find_element_by_xpath(ticker_xpath).text
        stock.append(ticker)
        # print(ticker)
        company = driver.find_element_by_xpath(company_xpath).text
        stock.append(company)
        # print(company)
        low = driver.find_element_by_xpath(low_xpath).text
        stock.append(low)
        # print(low)
        high = driver.find_element_by_xpath(high_xpath).text
        stock.append(high)
        # print(high)
        current = driver.find_element_by_xpath(current_xpath).text
        stock.append(current)
        # print(current)
        open = driver.find_element_by_xpath(open_xpath).text
        stock.append(open)
        # print(open)
        volume = driver.find_element_by_xpath(volume_xpath).text
        stock.append(volume)
        # print(volume)

        stocks.append(stock)

        # stocks.append(sector + ticker + company + low + high + current + volume)
        # print("Stock",stocks)
    
    except NoSuchElementException:
        pass

print(len(stocks))

# for count, company in enumerate(companies):
#     companies=company.get_text()
#     # print(company)
#     # print(count)

# for sector in sectors:
#     sector=sector.get_text()
#     # print(sector)


print(stocks[0])
# Out:
# 70
# ['EGAD Eaagads Ltd 10.00 15.00 12.75 13.60 13.55 12.40 1.15 9.27% ▲ 6,000 -', 'EGAD', 'Eaagads Ltd', '12.75', '13.60', '13.55', '12.40', '6,000']

# %%
url='https://live.mystocks.co.ke/price_list/20211103'

driver.get(url)
stocks=[]
tickers=[]

for i in range(3,88):
    try:
        sector_xpath = '//*[@id="pricelist"]/tbody/tr[{}]'.format(i)
        ticker_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[1]'.format(i)
        company_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[2]/a'.format(i)
        low_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[5]'.format(i)
        high_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[6]'.format(i)
        current_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[7]'.format(i)
        open_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[8]'.format(i)
        volume_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[12]'.format(i)


        stock=[]
        sector = driver.find_element_by_xpath(sector_xpath).text
        stock.append(sector)
        ticker = driver.find_element_by_xpath(ticker_xpath).text
        stock.append(ticker)
        company = driver.find_element_by_xpath(company_xpath).text
        stock.append(company)
        low = driver.find_element_by_xpath(low_xpath).text
        stock.append(low)
        high = driver.find_element_by_xpath(high_xpath).text
        stock.append(high)
        current = driver.find_element_by_xpath(current_xpath).text
        stock.append(current)
        open = driver.find_element_by_xpath(open_xpath).text
        stock.append(open)
        volume = driver.find_element_by_xpath(volume_xpath).text
        stock.append(volume)

        stocks.append(stock)

    except NoSuchElementException:
        pass

# %%
fieldnames = ['Date', 'Open', 'High',
                  'Low', 'Close', 'Adj Close', 'Volume']

for stock in stocks:
    ticker = stock[1]

    try:
        try:
            low = float(stock[3])
            high = float(stock[4])
            current = float(stock[5])
            open = float(stock[6])
            volume = float(stock[7])

        except ValueError:
            high = stock[4].replace('-', "0")
            current = stock[5].replace('-', "0")
            open = stock[6].replace('-', "0")
            volume = stock[7].replace('-', "0")
            low = stock[3].replace('-', "0")

    except ValueError:
        low = float(stock[3].replace(',', ""))
        high = float(stock[4].replace(',', ""))
        current = float(stock[5].replace(',', ""))
        open = float(stock[6].replace(',', ""))
        volume = float(stock[7].replace(',', ""))
    
    print(ticker, low, high, current, open, volume)

# %%
for date in date_list:
  date = str(date).replace('-', '')
  url='https://live.mystocks.co.ke/price_list/{}'.format(date)

  page = requests.get(url)

  soup = BeautifulSoup(page.content, "html.parser")

  # tbody = soup.find('div', id='main').find_all('table')
  try:
    # tbody = soup.find('div', id='main').find('table').find('tbody').find_all('tr')
    # tbody = soup.find('div', id='main').find('table', id='pricelist').find_all('tr', class_="row")

    def rowgetDataText(tr, coltag='td'):  # td (data) or th (header)
        return [td.get_text(strip=True) for td in tr.find_all(coltag)]

    current = []
    trs = soup.find('div', id='main').find('table', id='pricelist').find('tr', class_="row").find_all('td')

    trs2 = trs.find('td', class_="b2").find('h3').get_text()

    headerow = rowgetDataText(trs[0], 'th')
    if headerow:  # if there is a header row include first
        current.append(headerow)

  except AttributeError:
    pass

  print("Found",trs2)

# %%
tickers=[]
url='https://live.mystocks.co.ke/price_list/20211103'
driver = webdriver.Chrome(
    "/usr/bin/chromedriver", options=options)


if not os.path.exists('historical_nse_dfs'):
        os.makedirs('historical_nse_dfs')

for i in range(3,88):
  ticker_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[1]'.format(i)
  ticker = driver.find_element_by_xpath(ticker_xpath).text

  tickers.append(ticker)

  try:
    sector_xpath='//*[@id="pricelist"]/tbody/tr[{}]/td/h3'.format(i)
    sector = driver.find_element_by_xpath(sector_xpath).text
    if sector:
      tickers.remove(sector)
    
    else:
      pass
  
  except NoSuchElementException:
    pass

for ticker in tickers:
  if not os.path.exists("historical_nse_dfs/{}.csv".format(ticker)):
      try:
          with open('historical_nse_dfs/{}.csv'.format(ticker), "w", encoding='UTF8', newline='') as f:
            pass
              # csv_writer = csv.DictWriter(
              #     f, fieldnames=fieldnames)
              # csv_writer.writeheader()
              # csv_writer.writerows(rows)
      except RemoteDataError as exp:
          print('Unable to write data to: {}'.format(ticker))
  # else:
  #     try:
  #         with open('historical_nse_dfs/{}.csv'.format(ticker), "a", encoding='UTF8', newline='') as f:
  #             csv_writer = csv.DictWriter(
  #                 f, fieldnames=fieldnames)
  #             csv_writer.writerows(rows)
  #     except RemoteDataError as exp:
  #         print('Unable to read data from: {}'.format(ticker))

# %%
def get_historical_data():
    base = datetime.datetime.today().date()
    date_list = [base - datetime.timedelta(days=x) for x in range(5000)]

    stocks=[]

    for count, date in enumerate(date_list):
        date=str(date)
        asin = str(date).replace('-', '')
        url='https://live.mystocks.co.ke/price_list/{}'.format(asin)

        driver.get(url)

        for i in range(3,88):
            try:
                sector_xpath = '//*[@id="pricelist"]/tbody/tr[{}]'.format(i)
                ticker_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[1]'.format(i)
                company_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[2]/a'.format(i)
                low_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[5]'.format(i)
                high_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[6]'.format(i)
                current_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[7]'.format(i)
                open_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[8]'.format(i)
                volume_xpath = '//*[@id="pricelist"]/tbody/tr[{}]/td[12]'.format(i)


                stock=[]
                stock.append(date)
                sector = driver.find_element_by_xpath(sector_xpath).text
                stock.append(sector)
                ticker = driver.find_element_by_xpath(ticker_xpath).text
                stock.append(ticker)
                company = driver.find_element_by_xpath(company_xpath).text
                stock.append(company)
                low = driver.find_element_by_xpath(low_xpath).text
                stock.append(low)
                high = driver.find_element_by_xpath(high_xpath).text
                stock.append(high)
                current = driver.find_element_by_xpath(current_xpath).text
                stock.append(current)
                open = driver.find_element_by_xpath(open_xpath).text
                stock.append(open)
                volume = driver.find_element_by_xpath(volume_xpath).text
                stock.append(volume)

                stocks.append(stock)

            except NoSuchElementException:
                pass
        
        if count % 10 == 0:
            print(count)

    return stocks

stocks=get_historical_data()
# Out:
# 0
# 10
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-32-697d333930a9> in <module>
#      53     return stocks
#      54
# ---> 55 stocks=get_historical_data()
#
# <ipython-input-32-697d333930a9> in get_historical_data()
#      10         url='https://live.mystocks.co.ke/price_list/{}'.format(asin)
#      11
# ---> 12         driver.get(url)
#      13
#      14         for i in range(3,88):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: headless chrome=93.0.4577.63)

# %%
def save_historical_data():
    if not os.path.exists('historical_nse_dfs'):
            os.makedirs('historical_nse_dfs')

    fieldnames = ['Date', 'Open', 'Low', 'High', 'Close', 'Adj Close', 'Volume']

    for count, stock in enumerate(stocks):
        ticker = stock[2]
        date=stock[0]
        print(ticker)

        try:
            try:
                low = float(stock[4])
                high = float(stock[5])
                close = float(stock[6])
                start = float(stock[7])
                volume = float(stock[8])

            except ValueError:
                low = stock[4].replace('-', "0")
                high = stock[5].replace('-', "0")
                close = stock[6].replace('-', "0")
                start = stock[7].replace('-', "0")
                volume = stock[8].replace('-', "0")

        except ValueError:
            low = float(stock[4].replace(',', ""))
            high = float(stock[5].replace(',', ""))
            close = float(stock[6].replace(',', ""))
            start = float(stock[7].replace(',', ""))
            volume = float(stock[8].replace(',', ""))
        
        # print(date, ticker, low, high, close, start, volume)

        rows = [{
                'Date': date,
                'Open': start,
                'Low': low,
                'High': high,
                'Close': close,
                'Adj Close': close,
                'Volume': volume,
            }]

        if os.path.exists("historical_nse_dfs/{}.csv".format(ticker)):
            with open('historical_nse_dfs/{}.csv'.format(ticker), "a", encoding='UTF8', newline='') as f:
                    print('Appending')
                    csv_writer = csv.DictWriter(
                        f, fieldnames=fieldnames)
                    csv_writer.writerows(rows)

        else:
            with open("historical_nse_dfs/{}.csv".format(ticker), "w", encoding='UTF8', newline='') as f:
                    print('Writing')
                    csv_writer = csv.DictWriter(
                        f, fieldnames=fieldnames)
                    csv_writer.writeheader()
                    csv_writer.writerows(rows)
        
        if count % 10 == 0:
            print(count)

save_historical_data()
# Out:
# EGAD
# Writing
# 0
# KUKZ
# Writing
# KAPC
# Writing
# LIMT
# Writing
# SASN
# Writing
# WTK
# Writing
# CGEN
# Writing
# ABSA
# Writing
# BKG
# Writing
# COOP
# Writing
# DTK
# Writing
# 10
# EQTY
# Writing
# HFCK
# Writing
# IMH
# Writing
# KCB
# Writing
# NBK
# Writing
# NCBA
# Writing
# SBIC
# Writing
# SCBK
# Writing
# DCON
# Writing
# EVRD
# Writing
# 20
# XPRS
# Writing
# KQ
# Writing
# LKL
# Writing
# NBV
# Writing
# NMG
# Writing
# SMER
# Writing
# SGL
# Writing
# TPSE
# Writing
# UCHM
# Writing
# SCAN
# Writing
# 30
# ARM
# Writing
# BAMB
# Writing
# CRWN
# Writing
# CABL
# Writing
# PORT
# Writing
# KEGN
# Writing
# KPLC-P4
# Writing
# KPLC-P7
# Writing
# KPLC
# Writing
# TOTL
# Writing
# 40
# UMME
# Writing
# BRIT
# Writing
# CIC
# Writing
# JUB
# Writing
# KNRE
# Writing
# LBTY
# Writing
# SLAM
# Writing
# CTUM
# Writing
# HAFR
# Writing
# KURV
# Writing
# 50
# OCH
# Writing
# TCL
# Writing
# NSE
# Writing
# BOC
# Writing
# BAT
# Writing
# CARB
# Writing
# EABL
# Writing
# FTGH
# Writing
# ORCH
# Writing
# UNGA
# Writing
# 60
# SCOM
# Writing
# FAHR
# Writing
# GLD
# Writing
# ^FNK15
# Writing
# ^FNK25
# Writing
# ^N20I
# Writing
# ^N25I
# Writing
# ^NASI
# Writing
# ^ZKEQTK
# Writing
# EGAD
# Appending
# 70
# KUKZ
# Appending
# KAPC
# Appending
# LIMT
# Appending
# SASN
# Appending
# WTK
# Appending
# CGEN
# Appending
# ABSA
# Appending
# BKG
# Appending
# COOP
# Appending
# DTK
# Appending
# 80
# EQTY
# Appending
# HFCK
# Appending
# IMH
# Appending
# KCB
# Appending
# NBK
# Appending
# NCBA
# Appending
# SBIC
# Appending
# SCBK
# Appending
# DCON
# Appending
# EVRD
# Appending
# 90
# XPRS
# Appending
# KQ
# Appending
# LKL
# Appending
# NBV
# Appending
# NMG
# Appending
# SMER
# Appending
# SGL
# Appending
# TPSE
# Appending
# UCHM
# Appending
# SCAN
# Appending
# 100
# ARM
# Appending
# BAMB
# Appending
# CRWN
# Appending
# CABL
# Appending
# PORT
# Appending
# KEGN
# Appending
# KPLC-P4
# Appending
# KPLC-P7
# Appending
# KPLC
# Appending
# TOTL
# Appending
# 110
# UMME
# Appending
# BRIT
# Appending
# CIC
# Appending
# JUB
# Appending
# KNRE
# Appending
# LBTY
# Appending
# SLAM
# Appending
# CTUM
# Appending
# HAFR
# Appending
# KURV
# Appending
# 120
# OCH
# Appending
# TCL
# Appending
# NSE
# Appending
# BOC
# Appending
# BAT
# Appending
# CARB
# Appending
# EABL
# Appending
# FTGH
# Appending
# ORCH
# Appending
# UNGA
# Appending
# 130
# SCOM
# Appending
# FAHR
# Appending
# GLD
# Appending
# ^FNK15
# Appending
# ^FNK25
# Appending
# ^N20I
# Appending
# ^N25I
# Appending
# ^NASI
# Appending
# ^ZKEQTK
# Appending
# EGAD
# Appending
# 140
# KUKZ
# Appending
# KAPC
# Appending
# LIMT
# Appending
# SASN
# Appending
# WTK
# Appending
# CGEN
# Appending
# ABSA
# Appending
# BKG
# Appending
# COOP
# Appending
# DTK
# Appending
# 150
# EQTY
# Appending
# HFCK
# Appending
# IMH
# Appending
# KCB
# Appending
# NBK
# Appending
# NCBA
# Appending
# SBIC
# Appending
# SCBK
# Appending
# DCON
# Appending
# EVRD
# Appending
# 160
# XPRS
# Appending
# KQ
# Appending
# LKL
# Appending
# NBV
# Appending
# NMG
# Appending
# SMER
# Appending
# SGL
# Appending
# TPSE
# Appending
# UCHM
# Appending
# SCAN
# Appending
# 170
# ARM
# Appending
# BAMB
# Appending
# CRWN
# Appending
# CABL
# Appending
# PORT
# Appending
# KEGN
# Appending
# KPLC-P4
# Appending
# KPLC-P7
# Appending
# KPLC
# Appending
# TOTL
# Appending
# 180
# UMME
# Appending
# BRIT
# Appending
# CIC
# Appending
# JUB
# Appending
# KNRE
# Appending
# LBTY
# Appending
# SLAM
# Appending
# CTUM
# Appending
# HAFR
# Appending
# KURV
# Appending
# 190
# OCH
# Appending
# TCL
# Appending
# NSE
# Appending
# BOC
# Appending
# BAT
# Appending
# CARB
# Appending
# EABL
# Appending
# FTGH
# Appending
# ORCH
# Appending
# UNGA
# Appending
# 200
# SCOM
# Appending
# FAHR
# Appending
# GLD
# Appending
# ^FNK15
# Appending
# ^FNK25
# Appending
# ^N20I
# Appending
# ^N25I
# Appending
# ^NASI
# Appending
# ^ZKEQTK
# Appending
# EGAD
# Appending
# 210
# KUKZ
# Appending
# KAPC
# Appending
# LIMT
# Appending
# SASN
# Appending
# WTK
# Appending
# CGEN
# Appending
# ABSA
# Appending
# BKG
# Appending
# COOP
# Appending
# DTK
# Appending
# 220
# EQTY
# Appending
# HFCK
# Appending
# IMH
# Appending
# KCB
# Appending
# NBK
# Appending
# NCBA
# Appending
# SBIC
# Appending
# SCBK
# Appending
# DCON
# Appending
# EVRD
# Appending
# 230
# XPRS
# Appending
# KQ
# Appending
# LKL
# Appending
# NBV
# Appending
# NMG
# Appending
# SMER
# Appending
# SGL
# Appending
# TPSE
# Appending
# UCHM
# Appending
# SCAN
# Appending
# 240
# ARM
# Appending
# BAMB
# Appending
# CRWN
# Appending
# CABL
# Appending
# PORT
# Appending
# KEGN
# Appending
# KPLC-P4
# Appending
# KPLC-P7
# Appending
# KPLC
# Appending
# TOTL
# Appending
# 250
# UMME
# Appending
# BRIT
# Appending
# CIC
# Appending
# JUB
# Appending
# KNRE
# Appending
# LBTY
# Appending
# SLAM
# Appending
# CTUM
# Appending
# HAFR
# Appending
# KURV
# Appending
# 260
# OCH
# Appending
# TCL
# Appending
# NSE
# Appending
# BOC
# Appending
# BAT
# Appending
# CARB
# Appending
# EABL
# Appending
# FTGH
# Appending
# ORCH
# Appending
# UNGA
# Appending
# 270
# SCOM
# Appending
# FAHR
# Appending
# GLD
# Appending
# ^FNK15
# Appending
# ^FNK25
# Appending
# ^N20I
# Appending
# ^N25I
# Appending
# ^NASI
# Appending
# ^ZKEQTK
# Appending
# EGAD
# Appending
# 280
# KUKZ
# Appending
# KAPC
# Appending
# LIMT
# Appending
# SASN
# Appending
# WTK
# Appending
# CGEN
# Appending
# ABSA
# Appending
# BKG
# Appending
# COOP
# Appending
# DTK
# Appending
# 290
# EQTY
# Appending
# HFCK
# Appending
# IMH
# Appending
# KCB
# Appending
# NBK
# Appending
# NCBA
# Appending
# SBIC
# Appending
# SCBK
# Appending
# DCON
# Appending
# EVRD
# Appending
# 300
# XPRS
# Appending
# KQ
# Appending
# LKL
# Appending
# NBV
# Appending
# NMG
# Appending
# SMER
# Appending
# SGL
# Appending
# TPSE
# Appending
# UCHM
# Appending
# SCAN
# Appending
# 310
# ARM
# Appending
# BAMB
# Appending
# CRWN
# Appending
# CABL
# Appending
# PORT
# Appending
# KEGN
# Appending
# KPLC-P4
# Appending
# KPLC-P7
# Appending
# KPLC
# Appending
# TOTL
# Appending
# 320
# UMME
# Appending
# BRIT
# Appending
# CIC
# Appending
# JUB
# Appending
# KNRE
# Appending
# LBTY
# Appending
# SLAM
# Appending
# CTUM
# Appending
# HAFR
# Appending
# KURV
# Appending
# 330
# OCH
# Appending
# TCL
# Appending
# NSE
# Appending
# BOC
# Appending
# BAT
# Appending
# CARB
# Appending
# EABL
# Appending
# FTGH
# Appending
# ORCH
# Appending
# UNGA
# Appending
# 340
# SCOM
# Appending
# FAHR
# Appending
# GLD
# Appending
# ^FNK15
# Appending
# ^FNK25
# Appending
# ^N20I
# Appending
# ^N25I
# Appending
# ^NASI
# Appending
# ^ZKEQTK
# Appending

# %%
def save_historical_data():
    fieldnames = ['Date', 'Open', 'Low', 'High', 'Close', 'Adj Close', 'Volume']

    for stock in stocks:
        entry = stock[2]
        date=stock[0]
        low = (stock[4])
        high = (stock[5])
        close = (stock[6])
        start = (stock[7])
        volume = (stock[8])

        # print(date, entry, low, high, close, start, volume)

        rows = [{
                'Date': date,
                'Open': start,
                'Low': low,
                'High': high,
                'Close': close,
                'Adj Close': close,
                'Volume': volume,
            }]

        if os.path.exists("historical_nse_dfs/{}.csv".format(entry)):
            file_name='historical_nse_dfs/{}.csv'.format(entry)
            with open(file_name, "a", encoding='UTF8', newline='') as f:
                    csv_writer = csv.DictWriter(f, fieldnames=fieldnames)
                    csv_writer.writerows(rows)

        else:
            with open("historical_nse_dfs/{}.csv".format(entry), "w", encoding='UTF8', newline='') as f:
                    csv_writer = csv.DictWriter(f, fieldnames=fieldnames)
                    csv_writer.writeheader()
                    csv_writer.writerows(rows)

save_historical_data()
